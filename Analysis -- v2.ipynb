# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sqlite3
from tqdm.notebook import tqdm

# %%
fresh_query = """
SELECT from_npi, to_npi, patient_count, ProviderFirstName AS from_npi_First_Name, [ProviderLastName(LegalName)] AS from_npi_Last_Name, [ProviderOrganizationName(LegalBusinessName)] AS from_npi_Facility_Name, HealthcareProviderTaxonomyCode AS from_npi_HealthcareProviderTaxonomyCode, ProviderBusinessPracticeLocationAddressCityName AS from_npi_ProviderBusinessPracticeLocationAddressCityName 
FROM hop
INNER JOIN [nppes]
ON from_npi = NPI
WHERE ProviderBusinessPracticeLocationAddressStateName = 'TN' AND HealthcareProviderPrimaryTaxonomySwitch = 'Y' AND ProviderBusinessPracticeLocationAddressCityName = 'NASHVILLE';
"""

with sqlite3.connect('NPPES_Data_Dissemination.sqlite') as db: 
    from_npi_elements = pd.read_sql(fresh_query, db)
    
from_npi_elements
# Out:
#           from_npi      to_npi  patient_count from_npi_First_Name  \
# 0       1922001957  1295726032             81             RICHARD
# 1       1922001957  1578584199            129             RICHARD
# 2       1154324192  1295726032            110           ELIZABETH
# 3       1154324192  1578584199            202           ELIZABETH
# 4       1235132408  1093741464            112               LEWIS
# ...            ...         ...            ...                 ...
# 135917  1104850130  1649228735             52                None
# 135918  1104850130  1700878360             85                None
# 135919  1104850130  1811955917             59                None
# 135920  1104850130  1861479545            217                None
# 135921  1104850130  1922039346            912                None
#
#        from_npi_Last_Name   from_npi_Facility_Name  \
# 0                 PRESLEY                     None
# 1                 PRESLEY                     None
# 2                OLDFIELD                     None
# 3                OLDFIELD                     None
# 4                BELLARDO                     None
# ...                   ...                      ...
# 135917               None  HEIKKI E KOSTAMAA MD PC
# 135918               None  HEIKKI E KOSTAMAA MD PC
# 135919               None  HEIKKI E KOSTAMAA MD PC
# 135920               None  HEIKKI E KOSTAMAA MD PC
# 135921               None  HEIKKI E KOSTAMAA MD PC
#
#        from_npi_HealthcareProviderTaxonomyCode  \
# 0                                   207V00000X
# 1                                   207V00000X
# 2                                   207V00000X
# 3                                   207V00000X
# 4                                   207V00000X
# ...                                        ...
# 135917                              207W00000X
# 135918                              207W00000X
# 135919                              207W00000X
# 135920                              207W00000X
# 135921                              207W00000X
#
#        from_npi_ProviderBusinessPracticeLocationAddressCityName
# 0                                               NASHVILLE
# 1                                               NASHVILLE
# 2                                               NASHVILLE
# 3                                               NASHVILLE
# 4                                               NASHVILLE
# ...                                                   ...
# 135917                                          NASHVILLE
# 135918                                          NASHVILLE
# 135919                                          NASHVILLE
# 135920                                          NASHVILLE
# 135921                                          NASHVILLE
#
# [135922 rows x 8 columns]

# %%
fresh_query = """
SELECT from_npi, to_npi, patient_count
FROM hop
INNER JOIN [nppes]
ON from_npi = NPI
WHERE ProviderBusinessPracticeLocationAddressStateName = 'TN' AND HealthcareProviderPrimaryTaxonomySwitch = 'Y' AND ProviderBusinessPracticeLocationAddressCityName = 'NASHVILLE';
"""

with sqlite3.connect('NPPES_Data_Dissemination.sqlite') as db: 
    fresh_table = pd.read_sql(fresh_query, db)
    
fresh_table

# %%
fresh_table.to_csv('fresh_table.csv')

# %%
fresh_table
# Out:
#           from_npi      to_npi  patient_count
# 0       1922001957  1295726032             81
# 1       1922001957  1578584199            129
# 2       1154324192  1295726032            110
# 3       1154324192  1578584199            202
# 4       1235132408  1093741464            112
# ...            ...         ...            ...
# 135917  1104850130  1649228735             52
# 135918  1104850130  1700878360             85
# 135919  1104850130  1811955917             59
# 135920  1104850130  1861479545            217
# 135921  1104850130  1922039346            912
#
# [135922 rows x 3 columns]

# %%
fresh_query = """
SELECT from_npi, to_npi, patient_count, ProviderFirstName AS to_npi_First_Name, [ProviderLastName(LegalName)] AS to_npi_Last_Name, [ProviderOrganizationName(LegalBusinessName)] AS to_npi_Facility_Name, HealthcareProviderTaxonomyCode AS to_npi_HealthcareProviderTaxonomyCode, ProviderBusinessPracticeLocationAddressCityName AS to_npi_ProviderBusinessPracticeLocationAddressCityName 
FROM hop
INNER JOIN [nppes]
ON to_npi = NPI
WHERE ProviderBusinessPracticeLocationAddressStateName = 'TN' AND HealthcareProviderPrimaryTaxonomySwitch = 'Y' AND ProviderBusinessPracticeLocationAddressCityName = 'NASHVILLE';
"""

with sqlite3.connect('NPPES_Data_Dissemination.sqlite') as db: 
    to_npi_elements = pd.read_sql(fresh_query, db)
    
to_npi_elements
# Out:
#           from_npi      to_npi  patient_count to_npi_First_Name  \
# 0       1295726032  1922001957             83           RICHARD
# 1       1578584199  1922001957            129           RICHARD
# 2       1093741464  1154324192             69         ELIZABETH
# 3       1104202761  1154324192             52         ELIZABETH
# 4       1295726032  1154324192            104         ELIZABETH
# ...            ...         ...            ...               ...
# 135480  1811955917  1104850130             52              None
# 135481  1861479545  1104850130            195              None
# 135482  1871529982  1104850130             80              None
# 135483  1922039346  1104850130            912              None
# 135484  1922057181  1104850130             43              None
#
#        to_npi_Last_Name     to_npi_Facility_Name  \
# 0               PRESLEY                     None
# 1               PRESLEY                     None
# 2              OLDFIELD                     None
# 3              OLDFIELD                     None
# 4              OLDFIELD                     None
# ...                 ...                      ...
# 135480             None  HEIKKI E KOSTAMAA MD PC
# 135481             None  HEIKKI E KOSTAMAA MD PC
# 135482             None  HEIKKI E KOSTAMAA MD PC
# 135483             None  HEIKKI E KOSTAMAA MD PC
# 135484             None  HEIKKI E KOSTAMAA MD PC
#
#        to_npi_HealthcareProviderTaxonomyCode  \
# 0                                 207V00000X
# 1                                 207V00000X
# 2                                 207V00000X
# 3                                 207V00000X
# 4                                 207V00000X
# ...                                      ...
# 135480                            207W00000X
# 135481                            207W00000X
# 135482                            207W00000X
# 135483                            207W00000X
# 135484                            207W00000X
#
#        to_npi_ProviderBusinessPracticeLocationAddressCityName
# 0                                               NASHVILLE
# 1                                               NASHVILLE
# 2                                               NASHVILLE
# 3                                               NASHVILLE
# 4                                               NASHVILLE
# ...                                                   ...
# 135480                                          NASHVILLE
# 135481                                          NASHVILLE
# 135482                                          NASHVILLE
# 135483                                          NASHVILLE
# 135484                                          NASHVILLE
#
# [135485 rows x 8 columns]

# %%
neo4j_output = pd.read_csv('neo4j_fresh_table_output.csv', encoding= 'unicode_escape')

# %%
neo4j_output
# Out:
#         ï»¿number  communityId
# 0      1003000126         4463
# 1      1003001066         4463
# 2      1003001363         2629
# 3      1003009176         2629
# 4      1003010661        15821
# ...           ...          ...
# 30811  1992987085         4435
# 30812  1992988257         1640
# 30813  1992993760         5141
# 30814  1992996292         4463
# 30815  1992998793         1640
#
# [30816 rows x 2 columns]

# %%
neo4j_output = neo4j_output.rename(columns = {'ï»¿number':'NPI'})

# %%
neo4j_query = """
SELECT NPI, ProviderFirstName, [ProviderLastName(LegalName)], [ProviderOrganizationName(LegalBusinessName)], EntityTypeCode, HealthcareProviderTaxonomyCode 
FROM [nppes]
WHERE ProviderBusinessPracticeLocationAddressStateName = 'TN' AND HealthcareProviderPrimaryTaxonomySwitch = 'Y' AND ProviderBusinessPracticeLocationAddressCityName = 'NASHVILLE';
"""

with sqlite3.connect('NPPES_Data_Dissemination.sqlite') as db: 
    neo4j_nppes_1 = pd.read_sql(neo4j_query, db)
    
neo4j_nppes_1
# Out:
#               NPI ProviderFirstName ProviderLastName(LegalName)  \
# 0      1922001957           RICHARD                     PRESLEY
# 1      1760485817               SAM                       MORAN
# 2      1154324192         ELIZABETH                    OLDFIELD
# 3      1770586786           SHERRIE                    RICHARDS
# 4      1629071832             ROYCE                      ADKINS
# ...           ...               ...                         ...
# 22486  1245690585            ASHLEY                    HARRISON
# 22487  1710638523              None                        None
# 22488  1053753541           JESSICA                     LESUEUR
# 22489  1922039346            HEIKKI                    KOSTAMAA
# 22490  1104850130              None                        None
#
#       ProviderOrganizationName(LegalBusinessName)  EntityTypeCode  \
# 0                                            None             1.0
# 1                                            None             1.0
# 2                                            None             1.0
# 3                                            None             1.0
# 4                                            None             1.0
# ...                                           ...             ...
# 22486                                        None             1.0
# 22487                       VORI MEDICAL NY, PLLC             2.0
# 22488                                        None             1.0
# 22489                                        None             1.0
# 22490                     HEIKKI E KOSTAMAA MD PC             2.0
#
#       HealthcareProviderTaxonomyCode
# 0                         207V00000X
# 1                         207V00000X
# 2                         207V00000X
# 3                         207V00000X
# 4                         207V00000X
# ...                              ...
# 22486                     122300000X
# 22487                     208100000X
# 22488                     152W00000X
# 22489                     207W00000X
# 22490                     207W00000X
#
# [22491 rows x 6 columns]

# %%
neo4j_nppes_2 = pd.merge(neo4j_nppes_1, neo4j_output, left_on = 'NPI', right_on = 'NPI')
neo4j_nppes_2
# Out:
#              NPI ProviderFirstName ProviderLastName(LegalName)  \
# 0     1922001957           RICHARD                     PRESLEY
# 1     1154324192         ELIZABETH                    OLDFIELD
# 2     1235132408             LEWIS                    BELLARDO
# 3     1225031461         VARALAXMI                      DASARI
# 4     1376546481           MELANIE                        DUNN
# ...          ...               ...                         ...
# 4851  1023000999             CLARA                      WOMACK
# 4852  1982897690           HABEEBA                        PARK
# 4853  1053753541           JESSICA                     LESUEUR
# 4854  1922039346            HEIKKI                    KOSTAMAA
# 4855  1104850130              None                        None
#
#      ProviderOrganizationName(LegalBusinessName)  EntityTypeCode  \
# 0                                           None             1.0
# 1                                           None             1.0
# 2                                           None             1.0
# 3                                           None             1.0
# 4                                           None             1.0
# ...                                          ...             ...
# 4851                                        None             1.0
# 4852                                        None             1.0
# 4853                                        None             1.0
# 4854                                        None             1.0
# 4855                     HEIKKI E KOSTAMAA MD PC             2.0
#
#      HealthcareProviderTaxonomyCode  communityId
# 0                        207V00000X         2396
# 1                        207V00000X         2396
# 2                        207V00000X         2396
# 3                        2085R0202X         2396
# 4                        207V00000X         2396
# ...                             ...          ...
# 4851                     207RN0300X         2683
# 4852                     2086S0127X        10737
# 4853                     152W00000X         2306
# 4854                     207W00000X         2306
# 4855                     207W00000X         2306
#
# [4856 rows x 7 columns]

# %%
taxonomy_nucc = pd.read_csv('nucc_taxonomy_230.csv', encoding= 'unicode_escape')

# %%
neo4j_nppes_taxonomy = pd.merge(neo4j_nppes_2, taxonomy_nucc, left_on = 'HealthcareProviderTaxonomyCode', right_on = "Code")

names = neo4j_nppes_taxonomy[['ProviderFirstName', 'ProviderLastName(LegalName)', 'communityId']]

names[names['ProviderLastName(LegalName)'] == 'RIDDICK']
# Out:
#      ProviderFirstName ProviderLastName(LegalName)  communityId
# 4724              JOHN                     RIDDICK         2683

# %%
neo4j_nppes_taxonomy.groupby('communityId')['Classification'].count().sort_values(ascending = False)
# Out:
# <AxesSubplot:xlabel='communityId'>

# %%
family_med_and_ortho = neo4j_nppes_taxonomy[neo4j_nppes_taxonomy['Classification'].isin(['Family Medicine', 'Orthopaedic Surgery'])]

# %%
family_med_and_ortho.groupby('communityId')['NPI'].count().sort_values(ascending = False).plot(kind = 'bar', color = 'orange')
plt.label
# Out:
# <AxesSubplot:xlabel='communityId'>

# %%
family_med_and_ortho.to_csv('family_med_and_ortho.csv')

# %%
Nashville_Hop = from_npi_elements.merge(to_npi_elements, left_on = ["from_npi", "to_npi", "patient_count"], right_on = ["from_npi", "to_npi", "patient_count"])

Nashville_Hop
# Out:
#          from_npi      to_npi  patient_count from_npi_First_Name  \
# 0      1922001957  1578584199            129             RICHARD
# 1      1154324192  1578584199            202           ELIZABETH
# 2      1235132408  1093826133             68               LEWIS
# 3      1235132408  1578584199            217               LEWIS
# 4      1235132408  1629025648             45               LEWIS
# ...           ...         ...            ...                 ...
# 58761  1104850130  1629025648             55                None
# 58762  1104850130  1649228735             52                None
# 58763  1104850130  1700878360             85                None
# 58764  1104850130  1811955917             59                None
# 58765  1104850130  1922039346            912                None
#
#       from_npi_Last_Name   from_npi_Facility_Name  \
# 0                PRESLEY                     None
# 1               OLDFIELD                     None
# 2               BELLARDO                     None
# 3               BELLARDO                     None
# 4               BELLARDO                     None
# ...                  ...                      ...
# 58761               None  HEIKKI E KOSTAMAA MD PC
# 58762               None  HEIKKI E KOSTAMAA MD PC
# 58763               None  HEIKKI E KOSTAMAA MD PC
# 58764               None  HEIKKI E KOSTAMAA MD PC
# 58765               None  HEIKKI E KOSTAMAA MD PC
#
#       from_npi_HealthcareProviderTaxonomyCode  \
# 0                                  207V00000X
# 1                                  207V00000X
# 2                                  207V00000X
# 3                                  207V00000X
# 4                                  207V00000X
# ...                                       ...
# 58761                              207W00000X
# 58762                              207W00000X
# 58763                              207W00000X
# 58764                              207W00000X
# 58765                              207W00000X
#
#       from_npi_ProviderBusinessPracticeLocationAddressCityName  \
# 0                                              NASHVILLE
# 1                                              NASHVILLE
# 2                                              NASHVILLE
# 3                                              NASHVILLE
# 4                                              NASHVILLE
# ...                                                  ...
# 58761                                          NASHVILLE
# 58762                                          NASHVILLE
# 58763                                          NASHVILLE
# 58764                                          NASHVILLE
# 58765                                          NASHVILLE
#
#       to_npi_First_Name to_npi_Last_Name                to_npi_Facility_Name  \
# 0                  None             None          TENNESSEE WOMEN'S CARE, PC
# 1                  None             None          TENNESSEE WOMEN'S CARE, PC
# 2                  None             None  INNER VISION WOMENS ULTRASOUND PLC
# 3                  None             None          TENNESSEE WOMEN'S CARE, PC
# 4                  None             None          SAINT THOMAS WEST HOSPITAL
# ...                 ...              ...                                 ...
# 58761              None             None          SAINT THOMAS WEST HOSPITAL
# 58762              None             None             TENNESSEE ONCOLOGY PLLC
# 58763              None             None           NEPHROLOGY ASSOCIATES, PC
# 58764              None             None             TENNESSEE ONCOLOGY PLLC
# 58765            HEIKKI         KOSTAMAA                                None
#
#       to_npi_HealthcareProviderTaxonomyCode  \
# 0                                207V00000X
# 1                                207V00000X
# 2                                2085R0202X
# 3                                207V00000X
# 4                                282N00000X
# ...                                     ...
# 58761                            282N00000X
# 58762                            207RH0003X
# 58763                            207RN0300X
# 58764                            207RH0003X
# 58765                            207W00000X
#
#       to_npi_ProviderBusinessPracticeLocationAddressCityName
# 0                                              NASHVILLE
# 1                                              NASHVILLE
# 2                                              NASHVILLE
# 3                                              NASHVILLE
# 4                                              NASHVILLE
# ...                                                  ...
# 58761                                          NASHVILLE
# 58762                                          NASHVILLE
# 58763                                          NASHVILLE
# 58764                                          NASHVILLE
# 58765                                          NASHVILLE
#
# [58766 rows x 13 columns]

# %%
Nashville_Hop_from_communities = Nashville_Hop.merge(neo4j_output, left_on = "from_npi", right_on = "NPI")

Nashville_Hop_from_communities
# Out:
#          from_npi      to_npi  patient_count from_npi_First_Name  \
# 0      1922001957  1578584199            129             RICHARD
# 1      1154324192  1578584199            202           ELIZABETH
# 2      1235132408  1093826133             68               LEWIS
# 3      1235132408  1578584199            217               LEWIS
# 4      1235132408  1629025648             45               LEWIS
# ...           ...         ...            ...                 ...
# 58761  1104850130  1629025648             55                None
# 58762  1104850130  1649228735             52                None
# 58763  1104850130  1700878360             85                None
# 58764  1104850130  1811955917             59                None
# 58765  1104850130  1922039346            912                None
#
#       from_npi_Last_Name   from_npi_Facility_Name  \
# 0                PRESLEY                     None
# 1               OLDFIELD                     None
# 2               BELLARDO                     None
# 3               BELLARDO                     None
# 4               BELLARDO                     None
# ...                  ...                      ...
# 58761               None  HEIKKI E KOSTAMAA MD PC
# 58762               None  HEIKKI E KOSTAMAA MD PC
# 58763               None  HEIKKI E KOSTAMAA MD PC
# 58764               None  HEIKKI E KOSTAMAA MD PC
# 58765               None  HEIKKI E KOSTAMAA MD PC
#
#       from_npi_HealthcareProviderTaxonomyCode  \
# 0                                  207V00000X
# 1                                  207V00000X
# 2                                  207V00000X
# 3                                  207V00000X
# 4                                  207V00000X
# ...                                       ...
# 58761                              207W00000X
# 58762                              207W00000X
# 58763                              207W00000X
# 58764                              207W00000X
# 58765                              207W00000X
#
#       from_npi_ProviderBusinessPracticeLocationAddressCityName  \
# 0                                              NASHVILLE
# 1                                              NASHVILLE
# 2                                              NASHVILLE
# 3                                              NASHVILLE
# 4                                              NASHVILLE
# ...                                                  ...
# 58761                                          NASHVILLE
# 58762                                          NASHVILLE
# 58763                                          NASHVILLE
# 58764                                          NASHVILLE
# 58765                                          NASHVILLE
#
#       to_npi_First_Name to_npi_Last_Name                to_npi_Facility_Name  \
# 0                  None             None          TENNESSEE WOMEN'S CARE, PC
# 1                  None             None          TENNESSEE WOMEN'S CARE, PC
# 2                  None             None  INNER VISION WOMENS ULTRASOUND PLC
# 3                  None             None          TENNESSEE WOMEN'S CARE, PC
# 4                  None             None          SAINT THOMAS WEST HOSPITAL
# ...                 ...              ...                                 ...
# 58761              None             None          SAINT THOMAS WEST HOSPITAL
# 58762              None             None             TENNESSEE ONCOLOGY PLLC
# 58763              None             None           NEPHROLOGY ASSOCIATES, PC
# 58764              None             None             TENNESSEE ONCOLOGY PLLC
# 58765            HEIKKI         KOSTAMAA                                None
#
#       to_npi_HealthcareProviderTaxonomyCode  \
# 0                                207V00000X
# 1                                207V00000X
# 2                                2085R0202X
# 3                                207V00000X
# 4                                282N00000X
# ...                                     ...
# 58761                            282N00000X
# 58762                            207RH0003X
# 58763                            207RN0300X
# 58764                            207RH0003X
# 58765                            207W00000X
#
#       to_npi_ProviderBusinessPracticeLocationAddressCityName         NPI  \
# 0                                              NASHVILLE      1922001957
# 1                                              NASHVILLE      1154324192
# 2                                              NASHVILLE      1235132408
# 3                                              NASHVILLE      1235132408
# 4                                              NASHVILLE      1235132408
# ...                                                  ...             ...
# 58761                                          NASHVILLE      1104850130
# 58762                                          NASHVILLE      1104850130
# 58763                                          NASHVILLE      1104850130
# 58764                                          NASHVILLE      1104850130
# 58765                                          NASHVILLE      1104850130
#
#        communityId
# 0             2396
# 1             2396
# 2             2396
# 3             2396
# 4             2396
# ...            ...
# 58761         2306
# 58762         2306
# 58763         2306
# 58764         2306
# 58765         2306
#
# [58766 rows x 15 columns]

# %%
Nashville_Hop_from_communities.merge(taxonomy_nucc, right_on = "HealthcareProviderTaxonomyCode", left_on = "Code")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [51], in <cell line: 1>()
# ----> 1 Nashville_Hop_from_communities.merge(taxonomy_nucc, right_on = "HealthcareProviderTaxonomyCode", left_on = "Code")
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:9345, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    9326 @Substitution("")
#    9327 @Appender(_merge_doc, indents=2)
#    9328 def merge(
#    (...)
#    9341     validate: str | None = None,
#    9342 ) -> DataFrame:
#    9343     from pandas.core.reshape.merge import merge
# -> 9345     return merge(
#    9346         self,
#    9347         right,
#    9348         how=how,
#    9349         on=on,
#    9350         left_on=left_on,
#    9351         right_on=right_on,
#    9352         left_index=left_index,
#    9353         right_index=right_index,
#    9354         sort=sort,
#    9355         suffixes=suffixes,
#    9356         copy=copy,
#    9357         indicator=indicator,
#    9358         validate=validate,
#    9359     )
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/merge.py:107, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      90 @Substitution("\nleft : DataFrame or named Series")
#      91 @Appender(_merge_doc, indents=0)
#      92 def merge(
#    (...)
#     105     validate: str | None = None,
#     106 ) -> DataFrame:
# --> 107     op = _MergeOperation(
#     108         left,
#     109         right,
#     110         how=how,
#     111         on=on,
#     112         left_on=left_on,
#     113         right_on=right_on,
#     114         left_index=left_index,
#     115         right_index=right_index,
#     116         sort=sort,
#     117         suffixes=suffixes,
#     118         copy=copy,
#     119         indicator=indicator,
#     120         validate=validate,
#     121     )
#     122     return op.get_result()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/merge.py:700, in _MergeOperation.__init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     693 self._cross = cross_col
#     695 # note this function has side effects
#     696 (
#     697     self.left_join_keys,
#     698     self.right_join_keys,
#     699     self.join_names,
# --> 700 ) = self._get_merge_keys()
#     702 # validate the merge keys dtypes. We may need to coerce
#     703 # to avoid incompatible dtypes
#     704 self._maybe_coerce_merge_keys()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/merge.py:1097, in _MergeOperation._get_merge_keys(self)
#    1095 if not is_rkey(rk):
#    1096     if rk is not None:
# -> 1097         right_keys.append(right._get_label_or_level_values(rk))
#    1098     else:
#    1099         # work-around for merge_asof(right_index=True)
#    1100         right_keys.append(right.index)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:1840, in NDFrame._get_label_or_level_values(self, key, axis)
#    1838     values = self.axes[axis].get_level_values(key)._values
#    1839 else:
# -> 1840     raise KeyError(key)
#    1842 # Check for duplicates
#    1843 if values.ndim > 1:
#
# KeyError: 'HealthcareProviderTaxonomyCode'

# %%
Nashville_Hop_from_communities.to_csv('Nashville_Hop_from_communities.csv')

# %%
facility_query = "SELECT NPI, [ProviderOrganizationName(LegalBusinessName)], ProviderBusinessPracticeLocationAddressPostalCode, HealthcareProviderTaxonomyCode FROM [nppes] WHERE EntityTypeCode = 2 AND ProviderBusinessPracticeLocationAddressCityName = 'NASHVILLE' AND ProviderBusinessPracticeLocationAddressStateName = 'TN' AND HealthcareProviderPrimaryTaxonomySwitch = 'Y' GROUP BY NPI, 'ProviderOrganizationName(LegalBusinessName)', ProviderBusinessPracticeLocationAddressPostalCode, HealthcareProviderTaxonomyCode"
    
facility_sqlite = pd.read_sql(facility_query, db)
    
facility_sqlite

# %%
provider_query = "SELECT NPI, ProviderFirstName, [ProviderLastName(LegalName)], ProviderNamePrefixText, ProviderNameSuffixText, ProviderCredentialText, HealthcareProviderTaxonomyCode FROM [NPPES] WHERE EntityTypeCode = 1 AND ProviderBusinessPracticeLocationAddressCityName = 'NASHVILLE' AND ProviderBusinessPracticeLocationAddressStateName = 'TN' AND HealthcareProviderPrimaryTaxonomySwitch = 'Y' AND HealthcareProviderTaxonomyCode NOT NULL GROUP BY NPI, NPI, ProviderFirstName, [ProviderLastName(LegalName)], ProviderNamePrefixText, ProviderNameSuffixText, ProviderCredentialText, HealthcareProviderTaxonomyCode"

provider = pd.read_sql(provider_query, db)

provider

# %%
taxonomy_nucc = pd.read_csv('nucc_taxonomy_230.csv', encoding= 'unicode_escape')

# %%
provider = provider.merge(taxonomy_nucc, left_on = "HealthcareProviderTaxonomyCode", right_on = "Code")
provider

# %%
provider['Classification'].unique()

# %%
facility = facility_sqlite.merge(taxonomy_nucc, left_on = "HealthcareProviderTaxonomyCode", right_on = "Code")
facility = facility[facility['Grouping'] == 'Hospitals']
facility

# %%
provider.to_sql('provider', db, if_exists = 'replace', index = False)

# %%
facility.to_sql('facility', db, if_exists = 'replace', index = False)

# %%
test_query = "SELECT Classification FROM provider"
provider_test = pd.read_sql(test_query, db)

provider_test

# %%
specialist_query = "SELECT hop.from_npi, hop.to_npi, hop.patient_count, hop.transaction_count, ProviderFirstName AS First_Name, [ProviderLastName(LegalName)] AS Last_Name, [ProviderOrganizationName(LegalBusinessName)] AS Hospital_Name, provider.Classification FROM provider INNER JOIN hop ON provider.NPI = hop.from_npi LEFT JOIN facility ON hop.to_npi = facility.NPI ORDER BY hop.patient_count DESC;"




specialist_test = pd.read_sql(specialist_query, db)

specialist_test

# %%
specialist_test['Hospital_Name'].unique()

# %%
specialist_test['Classification'].unique()

# %%
Nash_NPI = specialist_test[specialist_test.Hospital_Name.isin(['HCA HEALTH SERVICES OF TENNESSEE, INC.',
       'VANDERBILT UNIVERSITY MEDICAL CENTER',
       'HTI MEMORIAL HOSPITAL CORPORATION', 'SAINT THOMAS WEST HOSPITAL',
       'NASHVILLE GENERAL HOSPITAL', "BAPTIST WOMEN'S HEALTH CENTER LLC",
       'SELECT SPECIALTY HOSPITAL - NASHVILLE LLC', 'SETON CORPORATION',
       'CURAHEALTH NASHVILLE, LLC',
       'STATE OF TENNESSEE STATE F&A PAYROLL'])]

Nash_NPI

# %%
Nash_NPI_Minus_Vandy = specialist_test[specialist_test.Hospital_Name.isin(['HCA HEALTH SERVICES OF TENNESSEE, INC.',
       'HTI MEMORIAL HOSPITAL CORPORATION', 'SAINT THOMAS WEST HOSPITAL',
       'NASHVILLE GENERAL HOSPITAL', "BAPTIST WOMEN'S HEALTH CENTER LLC",
       'SELECT SPECIALTY HOSPITAL - NASHVILLE LLC', 'SETON CORPORATION',
       'CURAHEALTH NASHVILLE, LLC',
       'STATE OF TENNESSEE STATE F&A PAYROLL'])]

Nash_NPI_Minus_Vandy

# %%
Vandy_NPI = specialist_test[specialist_test.Hospital_Name.isin(['VANDERBILT UNIVERSITY MEDICAL CENTER'])]

Vandy_NPI

# %%
fig, ax = plt.subplots(figsize = (8,6))
g = sns.FacetGrid(Nash_NPI_Minus_Vandy, col="Last_Name")
g.map(sns.barplot(
    data = Nash_NPI_Minus_Vandy[Nash_NPI_Minus_Vandy.Classification.isin(['Family Medicine', 'Orthopaedic Surgery'])],
    x = 'Hospital_Name',
    y = 'patient_count',
    hue = 'Classification',
    ax = ax
))

# %%
Nash_Ortho_Fam = Nash_NPI[Nash_NPI.Classification.isin(['Orthopaedic Surgery', 'Family Medicine'])]

# %%
sns.barplot(data=gdp_df.groupby(['Continent'])['Country'].nunique().to_frame().reset_index().rename(columns = {'Country' : 'Total_Countries'}), y='Continent', x='Total_Countries', hue='Continent', dodge=False);

# %%
fig, ax = plt.subplots(figsize = (8,6))

sns.barplot(
    data = Nash_NPI[Nash_NPI.Classification.isin(['Orthopaedic Surgery'])],
    x = 'Hospital_Name',
    y = 'patient_count',
    ax = ax
)
plt.xticks(rotation = 90);

# %%
Nash_NPI[Nash_NPI.Classification.isin(['Family Medicine', 'Orthopaedic Surgery'])].groupby(['Hospital_Name'])['patient_count'].sum()

fig, ax = plt.subplots(figsize = (8,6))

sns.barplot(
    data = Nash_NPI[Nash_NPI.Classification.isin(['Family Medicine', 'Orthopaedic Surgery'])],
    x = 'Hospital_Name',
    y = y,
    hue = 'Classification',
    ax = ax
)
plt.xticks(rotation = 90);

# %%
fig, ax = plt.subplots(figsize = (20,6))

sns.histplot(
    data = Nash_NPI[Nash_NPI.Classification.isin(['Family Medicine', 'Orthopaedic Surgery'])],
    x = 'Hospital_Name',
    y = 'patient_count',
    hue = 'Classification',
    ax = ax
)
plt.xticks(rotation = 90);

# %%
Nash_Fam_Med = Nash_NPI[Nash_NPI.Classification.isin(['Orthopaedic Surgery'])]

Nash_Fam_Med['patient_count'].median()

# %%
fig, ax = plt.subplots(figsize = (25,10))

sns.boxplot(
    data = Nash_NPI_Minus_Vandy[Nash_NPI_Minus_Vandy.Classification.isin(['Family Medicine', 'Orthopaedic Surgery'])],
    x = 'Last_Name',
    y = 'patient_count',
    hue = 'Classification',
    ax = ax
)
plt.xticks(rotation = 90);

# %%
Nash_NPI_Minus_Vandy[Nash_NPI_Minus_Vandy['Last_Name'] == 'DEBOER']

# %%
neo4j_output = pd.read_csv('neo4j_output.csv', encoding= 'unicode_escape')

# %%
neo4j_output.to_sql('neo4j_output', db, if_exists = 'replace', index = False)

# %%
neo4j_output.head()

# %%
neo4j_output.groupby(['communityId'])['number'].count().sort_values(ascending = False).head(10)

# %%
neo4j_output.groupby(['communityId'])['number'].count().sort_values(ascending = False).head(10).plot(kind = 'bar')

# %%
specialist_group_id = "SELECT hop.from_npi, hop.to_npi, hop.patient_count, hop.transaction_count, ProviderFirstName AS First_Name, [ProviderLastName(LegalName)] AS Last_Name, [ProviderOrganizationName(LegalBusinessName)] AS Hospital_Name, provider.Classification, neo4j_output.communityId FROM provider INNER JOIN hop ON provider.NPI = hop.from_npi LEFT JOIN facility ON hop.to_npi = facility.NPI LEFT JOIN neo4j_output ON hop.from_npi = neo4j_output.number ORDER BY hop.patient_count DESC;"




specialist_group_id = pd.read_sql(specialist_group_id, db)

specialist_group_id

# %%
specialist_group_id.groupby(['communityId', 'Classification'])['patient_count'].sum().sort_values(ascending = False).head(10).plot(kind = 'bar', color = 'orange')

# %%
radiology_4384 = specialist_group_id.query('communityId == [4384] & Classification == "Internal Medicine"')

radiology_4384

# %%
radiology_4384.groupby(['from_npi'])['patient_count'].sum().sort_values(ascending = False)

# %%
specialist_group_id[specialist_group_id['from_npi'] == 1417131715].groupby(['from_npi'])['patient_count'].sum()

# %%
specialist_group_id.query('communityId == [4413]').groupby(['from_npi'])['patient_count'].sum().sort_values(ascending = False)

# %%
specialist_group_id.query('communityId == [4413] & from_npi == [1770519704]')[['Last_Name', 'First_Name']]

# %%
#4454

specialist_group_id.query('communityId == [4454]').groupby(['from_npi'])['patient_count'].sum().sort_values(ascending = False)

# %%
specialist_group_id.query('communityId == [4454] & from_npi == [1922091180]')

# %%
#113
specialist_group_id.query('communityId == [113]').groupby(['from_npi'])['patient_count'].sum().sort_values(ascending = False)

# %%
specialist_group_id.query('communityId == [113] & from_npi == [1093903544]')

# %%
#4702

specialist_group_id.query('communityId == [4702]').groupby(['from_npi'])['patient_count'].sum().sort_values(ascending = False)

# %%
specialist_group_id.query('communityId == [4702] & from_npi == [1306849765]')

# %%
#I'm seeing that there are a lot of missing values, primarily because our decisions building the 'specialist_list' table that limits what we can determine from the exploration. I'm going to attempt to read in additional items to better fill out the 'Community ID' picture.

Community_ID = """

SELECT 




specialist_group_id = pd.read_sql(specialist_group_id, db)

specialist_group_id
