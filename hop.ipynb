# %%
import pandas as pd
import sqlite3
from tqdm.notebook import tqdm

# %%
hop = pd.read_csv('data/DocGraph_Hop_Teaming_2018.csv', 
                          nrows = 100)

# %%
hop
# Out:
#       from_npi      to_npi  patient_count  transaction_count  \
# 0   1508062167  1730166109            350                370
# 1   1508065640  1730166109             25                 25
# 2   1508052093  1730166109             16                 16
# 3   1508172545  1730166109             14                 14
# 4   1508285131  1730166109             20                 21
# ..         ...         ...            ...                ...
# 95  1508178229  1730166893             31                 32
# 96  1508196445  1730166893             23                 24
# 97  1508811076  1730166935             14                 15
# 98  1508871252  1730166935             29                 31
# 99  1508845850  1730166943             23                 61
#
#     average_day_wait  std_day_wait
# 0             53.922        72.612
# 1             49.800        55.006
# 2            109.500        70.593
# 3            103.357        75.483
# 4             89.952        89.880
# ..               ...           ...
# 95            67.125        61.279
# 96            60.833        59.129
# 97            62.533        62.827
# 98            25.323        36.693
# 99             9.361        36.323
#
# [100 rows x 6 columns]

# %%
hop.shape
# Out:
# (100, 6)

# %%
chunks = pd.read_csv('data/DocGraph_Hop_Teaming_2018.csv', chunksize = 10000)

hop = []

for chunk in chunks: 
    chunk = chunk[(chunk['transaction_count'] >= 50) & (chunk['average_day_wait'] < 50)]
    hop.append(chunk)

# %%
hop = pd.concat(hop, ignore_index = True)
hop
# Out:
#             from_npi      to_npi  patient_count  transaction_count  \
# 0         1508085911  1730166125             58                 67
# 1         1508167040  1730166125             51                 51
# 2         1508863549  1730166125            340                391
# 3         1508867870  1730166125             50                 79
# 4         1508011040  1730166224            132                145
# ...              ...         ...            ...                ...
# 34176933  1417037664  1497939599             36                106
# 34176934  1417194903  1497939599             22                 70
# 34176935  1417406372  1497939599             21                 65
# 34176936  1417064825  1497940605             75                 79
# 34176937  1417909367  1497940662            131                136
#
#           average_day_wait  std_day_wait
# 0                   23.925        43.923
# 1                   28.196        52.876
# 2                   18.302        42.422
# 3                   12.658        26.402
# 4                    8.579        28.053
# ...                    ...           ...
# 34176933            19.330        42.407
# 34176934            16.629        30.598
# 34176935            20.123        37.750
# 34176936            10.418        34.744
# 34176937            21.051        30.066
#
# [34176938 rows x 6 columns]

# %%
db = sqlite3.connect('data/hop.sqlite')

chunks = pd.read_csv('data/DocGraph_Hop_Teaming_2018.csv', chunksize = 10000)
hop = []
for chunk in chunks:
    chunk = chunk[(chunk['transaction_count'] >= 50) & (chunk['average_day_wait'] < 50)]
    chunk.to_sql('hop', db, if_exists = 'append', index = False)
